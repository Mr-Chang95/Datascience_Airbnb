# %% [markdown]
# # Boston vs. Seattle Airbnb III
#
# **In this notebook(Part 3), I will be answering the question: Is it possible to predict the price with 5 features? If yes, compare the 2 cities.**

# %%
import warnings
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split
# %matplotlib inline
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Question 2: Is it possible to predict the price with 8 features? If yes, compare the 2 cities.
#
# ### Step 1: Examining and Cleaning Data

# %%
# import both datasets
seattle_listings = pd.read_csv('seattle_airbnb/listings.csv')
boston_listings = pd.read_csv('boston_airbnb/listings.csv')

# %%
#cleaning up the price
seattle_listings['price'] = seattle_listings['price'].map(lambda x: int(x[1:-3].replace(',','')))
# similair to what we did with neighbourhood, this time we will examine the overall city
sb.boxplot(x = 'price', data = seattle_listings)
plt.title("Boxplot Distribution Of Seattle Price");

# %% [markdown]
# **As we can see, there are quite alot of outliers. I will need to address these outliers which is what I'm going to do next. I will be using help from the link down below.** <br>
# > **Link: https://towardsdatascience.com/ways-to-detect-and-remove-the-outliers-404d16608dba**

# %%
# addressing and dropping the outliers using (1.5*IQR + Q3)
Q1 = seattle_listings['price'].quantile(0.25)
Q3 = seattle_listings['price'].quantile(0.75)
IQR = Q3 - Q1
upper = 1.5*(IQR) + Q3

upper
# Out:
# 262.5

# %%
seattle_listings = seattle_listings[seattle_listings['price'] <= upper]
seattle_listings.head(3)
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
#
#                                  name  \
# 0        Stylish Queen Anne Apartment
# 1  Bright & Airy Queen Anne Apartment
# 3                  Queen Anne Chateau
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 3  A charming apartment that sits atop Queen Anne...
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
# 1  Beautiful, hypoallergenic apartment in an extr...
# 3                                                NaN
#
#                                          description experiences_offered  \
# 0  Make your self at home in this charming one-be...                none
# 1  Chemically sensitive? We've removed the irrita...                none
# 3  A charming apartment that sits atop Queen Anne...                none
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  Queen Anne is a wonderful, truly functional vi...
# 3                                                NaN
#
#                                                notes  \
# 0                                                NaN
# 1  What's up with the free pillows?  Our home was...
# 3                                                NaN
#
#                                              transit  \
# 0                                                NaN
# 1  Convenient bus stops are just down the block, ...
# 3                                                NaN
#
#                                        thumbnail_url  \
# 0                                                NaN
# 1  https://a0.muscache.com/ac/pictures/14409893/f...
# 3                                                NaN
#
#                                           medium_url  \
# 0                                                NaN
# 1  https://a0.muscache.com/im/pictures/14409893/f...
# 3                                                NaN
#
#                                          picture_url  \
# 0  https://a1.muscache.com/ac/pictures/67560560/c...
# 1  https://a0.muscache.com/ac/pictures/14409893/f...
# 3  https://a0.muscache.com/ac/pictures/94146944/6...
#
#                                       xl_picture_url  host_id  \
# 0                                                NaN   956883
# 1  https://a0.muscache.com/ac/pictures/14409893/f...  5177328
# 3                                                NaN  9851441
#
#                                     host_url host_name  host_since  \
# 0   https://www.airbnb.com/users/show/956883     Maija  2011-08-11
# 1  https://www.airbnb.com/users/show/5177328    Andrea  2013-02-21
# 3  https://www.airbnb.com/users/show/9851441     Emily  2013-11-06
#
#                         host_location  \
# 0  Seattle, Washington, United States
# 1  Seattle, Washington, United States
# 3  Seattle, Washington, United States
#
#                                           host_about  host_response_time  \
# 0  I am an artist, interior designer, and run a s...  within a few hours
# 1  Living east coast/left coast/overseas.  Time i...      within an hour
# 3                                                NaN                 NaN
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0                96%                 100%                 f
# 1                98%                 100%                 t
# 3                NaN                  NaN                 f
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/ac/users/956883/profil...
# 1  https://a0.muscache.com/ac/users/5177328/profi...
# 3  https://a2.muscache.com/ac/users/9851441/profi...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/ac/users/956883/profil...         Queen Anne
# 1  https://a0.muscache.com/ac/users/5177328/profi...         Queen Anne
# 3  https://a2.muscache.com/ac/users/9851441/profi...         Queen Anne
#
#    host_listings_count  host_total_listings_count  \
# 0                  3.0                        3.0
# 1                  6.0                        6.0
# 3                  1.0                        1.0
#
#                                   host_verifications host_has_profile_pic  \
# 0               ['email', 'phone', 'reviews', 'kba']                    t
# 1  ['email', 'phone', 'facebook', 'linkedin', 're...                    t
# 3  ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
#
#   host_identity_verified                                             street  \
# 0                      t      Gilman Dr W, Seattle, WA 98119, United States
# 1                      t  7th Avenue West, Seattle, WA 98119, United States
# 3                      t  8th Avenue West, Seattle, WA 98119, United States
#
#   neighbourhood neighbourhood_cleansed neighbourhood_group_cleansed     city  \
# 0    Queen Anne        West Queen Anne                   Queen Anne  Seattle
# 1    Queen Anne        West Queen Anne                   Queen Anne  Seattle
# 3    Queen Anne        West Queen Anne                   Queen Anne  Seattle
#
#   state zipcode   market smart_location country_code        country  \
# 0    WA   98119  Seattle    Seattle, WA           US  United States
# 1    WA   98119  Seattle    Seattle, WA           US  United States
# 3    WA   98119  Seattle    Seattle, WA           US  United States
#
#     latitude   longitude is_location_exact property_type        room_type  \
# 0  47.636289 -122.371025                 t     Apartment  Entire home/apt
# 1  47.639123 -122.365666                 t     Apartment  Entire home/apt
# 3  47.638473 -122.369279                 t     Apartment  Entire home/apt
#
#    accommodates  bathrooms  bedrooms  beds  bed_type  \
# 0             4        1.0       1.0   1.0  Real Bed
# 1             4        1.0       1.0   1.0  Real Bed
# 3             3        1.0       0.0   2.0  Real Bed
#
#                                            amenities  square_feet  price  \
# 0  {TV,"Cable TV",Internet,"Wireless Internet","A...          NaN     85
# 1  {TV,Internet,"Wireless Internet",Kitchen,"Free...          NaN    150
# 3  {Internet,"Wireless Internet",Kitchen,"Indoor ...          NaN    100
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0          NaN           NaN              NaN          NaN                2
# 1    $1,000.00     $3,000.00          $100.00       $40.00                1
# 3      $650.00     $2,300.00              NaN          NaN                1
#
#   extra_people  minimum_nights  maximum_nights calendar_updated  \
# 0        $5.00               1             365      4 weeks ago
# 1        $0.00               2              90            today
# 3        $0.00               1            1125     6 months ago
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t               14               41               71
# 1                t               13               13               16
# 3                t                0                0                0
#
#    availability_365 calendar_last_scraped  number_of_reviews first_review  \
# 0               346            2016-01-04                207   2011-11-01
# 1               291            2016-01-04                 43   2013-08-19
# 3               143            2016-01-04                  0          NaN
#
#   last_review  review_scores_rating  review_scores_accuracy  \
# 0  2016-01-02                  95.0                    10.0
# 1  2015-12-29                  96.0                    10.0
# 3         NaN                   NaN                     NaN
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       10.0                   10.0
# 1                       10.0                   10.0
# 3                        NaN                    NaN
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                     9.0                 10.0
# 1                         10.0                    10.0                 10.0
# 3                          NaN                     NaN                  NaN
#
#   requires_license  license jurisdiction_names instant_bookable  \
# 0                f      NaN         WASHINGTON                f
# 1                f      NaN         WASHINGTON                f
# 3                f      NaN         WASHINGTON                f
#
#   cancellation_policy require_guest_profile_picture  \
# 0            moderate                             f
# 1              strict                             t
# 3            flexible                             f
#
#   require_guest_phone_verification  calculated_host_listings_count  \
# 0                                f                               2
# 1                                t                               6
# 3                                f                               1
#
#    reviews_per_month
# 0               4.07
# 1               1.48
# 3                NaN

# %% [markdown]
# **Now, it's time to determine the features that I am interested in. I will then divide them into independent variables X and dependent variable y.**
#
# **Interested Variables/Features For Seattle Dataset:** <br>
# > **`1.` host_response_rate <br> `2.` host_response_time <br> `3.` bedrooms <br> `4.` review_scores_rating <br> `5.` number_of_reviews <br> `6.` neighbourhood_group_cleansed <br> `7.` property_type <br> `8.` bathrooms**

# %%
X = seattle_listings[['neighbourhood_group_cleansed', 'host_response_time', 'host_response_rate',
                      'bedrooms', 'bathrooms', 'property_type', 'number_of_reviews','review_scores_rating']]
y = seattle_listings['price']

# %%
# cleaning up the columns' names
X = X.rename(columns = lambda x: str(x.replace('_',' ').strip().title()))

# %% [markdown]
# **Splitting dataset**

# %%
# random_state help: https://scikit-learn.org/stable/glossary.html#term-random_state
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .3, random_state= 42)

# %% [markdown]
# ### Step 2: Addressing And Handling Missing Data

# %%
# Checking for nulls
X_train.isnull().any()
# Out:
# Neighbourhood Group Cleansed    False
# Host Response Time               True
# Host Response Rate               True
# Bedrooms                         True
# Bathrooms                        True
# Property Type                    True
# Number Of Reviews               False
# Review Scores Rating             True
# dtype: bool

# %%
# after examination, it doesn't seem like there is any need to drop any of the columns
X_train.isnull().sum()/X_train.shape[0]
# Out:
# Neighbourhood Group Cleansed    0.0000
# Host Response Time              0.1272
# Host Response Rate              0.1272
# Bedrooms                        0.0020
# Bathrooms                       0.0052
# Property Type                   0.0004
# Number Of Reviews               0.0000
# Review Scores Rating            0.1688
# dtype: float64

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2500 entries, 922 to 3389
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Neighbourhood Group Cleansed  2500 non-null   object
#  1   Host Response Time            2182 non-null   object
#  2   Host Response Rate            2182 non-null   object
#  3   Bedrooms                      2495 non-null   float64
#  4   Bathrooms                     2487 non-null   float64
#  5   Property Type                 2499 non-null   object
#  6   Number Of Reviews             2500 non-null   int64
#  7   Review Scores Rating          2078 non-null   float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 175.8+ KB

# %%
# Viewing the head to make imputation decisions
# For numeric variables, I will be replacing them with the mean
# For categorical variables, it makes more sense to replace them with the mode
X_train.head()
# Out:
#      Neighbourhood Group Cleansed  Host Response Time Host Response Rate  \
# 922                  Central Area        within a day               100%
# 1671                     Downtown      within an hour               100%
# 3691          Other neighborhoods  within a few hours               100%
# 1878                 West Seattle      within an hour               100%
# 2088                  Beacon Hill        within a day               100%
#
#       Bedrooms  Bathrooms Property Type  Number Of Reviews  \
# 922        1.0        1.0         House                 10
# 1671       1.0        1.0     Apartment                  3
# 3691       1.0        1.0         House                 58
# 1878       1.0        1.0     Townhouse                 27
# 2088       2.0        1.0     Apartment                 99
#
#       Review Scores Rating
# 922                   96.0
# 1671                 100.0
# 3691                  94.0
# 1878                  96.0
# 2088                  97.0

# %%
# replace categorical nulls with mode in X_train and X_test
X_train['Host Response Time'] = X_train.loc[:,'Host Response Time'].fillna(X_train['Host Response Time'].mode()[0])
X_train['Host Response Rate'] = X_train.loc[:,'Host Response Rate'].fillna(X_train['Host Response Rate'].mode()[0])
X_train['Property Type'] = X_train.loc[:,'Property Type'].fillna(X_train['Property Type'].mode()[0])

X_test['Host Response Time'] = X_test.loc[:,'Host Response Time'].fillna(X_test['Host Response Time'].mode()[0])
X_test['Host Response Rate'] = X_test.loc[:,'Host Response Rate'].fillna(X_test['Host Response Rate'].mode()[0])
X_test['Property Type'] = X_test.loc[:,'Property Type'].fillna(X_test['Property Type'].mode()[0])

# %%
# replace numeric nulls with mean in X_train and X_test
X_train['Bedrooms'] = X_train.loc[:,'Bedrooms'].fillna(X_train['Bedrooms'].mean())
X_train['Bathrooms'] = X_train.loc[:,'Bathrooms'].fillna(X_train['Bathrooms'].mean())
X_train['Review Scores Rating'] = X_train.loc[:,'Review Scores Rating'].fillna(X_train['Review Scores Rating'].mean())

X_test['Bedrooms'] = X_test.loc[:,'Bedrooms'].fillna(X_test['Bedrooms'].mean())
X_test['Bathrooms'] = X_test.loc[:,'Bathrooms'].fillna(X_test['Bathrooms'].mean())
X_test['Review Scores Rating'] = X_test.loc[:,'Review Scores Rating'].fillna(X_test['Review Scores Rating'].mean())

# %% [markdown]
# ### Step 3: Encoding and Predicting Model

# %%
#Encoding categorical values
# help - https://www.youtube.com/watch?v=irHhDMbw3xo&t=901s
# help - https://stackoverflow.com/questions/64656728/using-make-column-transformer-for-categorical-variables-giving-error-during-fit
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
col_trans = make_column_transformer((OneHotEncoder(handle_unknown = 'ignore'),
                                     ['Neighbourhood Group Cleansed','Host Response Time',
                                      'Host Response Rate','Property Type']),
                                    remainder='passthrough')
X_train = col_trans.fit_transform(X_train).toarray()
X_test = col_trans.transform(X_test).toarray()

# %% [markdown]
# #### Linear Regression Method

# %%
# Create linear regression object and train the model using the training sets
lm_model = LinearRegression(normalize = True).fit(X_train, y_train)

# %%
# Make predictions using the testing and train set
y_test_pred = lm_model.predict(X_test)
y_train_pred = lm_model.predict(X_train)

# %%
# score using model
test_score = r2_score(y_test, y_test_pred)
train_score = r2_score(y_train, y_train_pred)

print(f"R-Squared for test data: {test_score}")
print(f"R-Squared for train data: {train_score}")
# Out:
# R-Squared for test data: -1.5474230108318648e+23
# R-Squared for train data: 0.4353396555494863

# %% [markdown]
# **As you can see from above, the model is terrible and isn't even close; this is indicated by the negative r-squared value for the test data. Therefore, I will need to find a different modeling method. To do that, I used the link below to search for different models to try out. I complemented this with many other outside research.**
# > **Helpful Link:** https://www.educative.io/blog/scikit-learn-cheat-sheet-classification-regression-methods
#
# **If you take a look near the bottom, there are additional linear regression methods that are suggested. I will be trying out as many as I can.**
#
# #### Support Vector Machine Method

# %%
# help -https://www.javatpoint.com/machine-learning-support-vector-machine-algorithm
# help - https://towardsdatascience.com/support-vector-machines-explained-with-python-examples-cb65e8172c85
from sklearn.svm import SVR
model = SVR(kernel = 'linear')
model.fit(X_train, y_train)

# Predicting train and test(same steps as above)
y_pred_test = model.predict(X_test)
y_pred_train = model.predict(X_train)

# r2_score
svr_model_train = r2_score(y_train, y_pred_train)
svr_model_test = r2_score(y_test, y_pred_test)

print(f"R-squared value for train data: {svr_model_train}")
print(f"R-squared value for test data: {svr_model_test}")

#mean_square_error help - https://www.statisticshowto.com/probability-and-statistics/statistics-definitions/mean-squared-error/
# more help - https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html
print(f"Average Missed Distance From Price: {mean_squared_error(y_test, y_pred_test, squared = False)}")
# Out:
# R-squared value for train data: 0.39828558893388966
# R-squared value for test data: 0.36973247235487805
# Average Missed Distance From Price: 40.914781541448406

# %% [markdown]
# #### Support Vector Machine Method Visuals

# %%
plt.rcParams['figure.figsize'] = [10, 6]

plt.scatter(y_test, y_pred_test, color = 'black')
plt.title('Scatter Plot Of Support Vector Machine Result')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price');

# %% [markdown]
# #### XGB Regressor Method

# %%
# help - https://thinkingneuron.com/how-to-create-an-xgboost-model-for-regression-in-python/
# help - https://stackoverflow.com/questions/58318685/how-to-hide-warnings-from-xgboost-library-in-jupyter
# we can use the sqrt of mean_squared_error, to get the distance from  line
from xgboost.sklearn import XGBRegressor
model = XGBRegressor('reg:linear',verbosity = 0)
model.fit(X_train, y_train)

# Predicting train and test(same steps as above)
y_pred_test = model.predict(X_test)
y_pred_train = model.predict(X_train)

# r2_score
xgb_model_train = r2_score(y_train, y_pred_train)
xgb_model_test = r2_score(y_test, y_pred_test)

print(f"R-squared value for train data: {xgb_model_train}")
print(f"R-squared value for test data: {xgb_model_test}")
print(f"Average Missed Distance From Price: {mean_squared_error(y_test, y_pred_test, squared = False)}")
# Out:
# R-squared value for train data: 0.7822738838469437
# R-squared value for test data: 0.4570009405371742
# Average Missed Distance From Price: 37.97670746708108

# %% [markdown]
# #### XGB Regressor Method Visuals

# %%
plt.rcParams['figure.figsize'] = [10, 6]

plt.scatter(y_test, y_pred_test, color = 'black')
plt.title('Scatter Plot Of XGB Regressor Result')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price');

# %% [markdown]
# #### Bayesian Ridge Method

# %%
from sklearn.linear_model import BayesianRidge

model = BayesianRidge()
model.fit(X_train, y_train)

# Predicting train and test(same steps as above)
y_pred_test = model.predict(X_test)
y_pred_train = model.predict(X_train)

# r2_score
baye_model_train = r2_score(y_train, y_pred_train)
baye_model_test = r2_score(y_test, y_pred_test)

print(f"R-squared value for train data: {baye_model_train}")
print(f"R-squared value for test data: {baye_model_test}")
print(f"Average Missed Distance From Price: {mean_squared_error(y_test, y_pred_test, squared = False)}")
# Out:
# R-squared value for train data: 0.4265742873361258
# R-squared value for test data: 0.3967437735491848
# Average Missed Distance From Price: 40.02844112055365

# %% [markdown]
# #### Bayesian Ridge Visuals

# %%
plt.rcParams['figure.figsize'] = [10, 6]

plt.scatter(y_test, y_pred_test, color = 'black')
plt.title('Scatter Plot Of Bayesian Ridge Result')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price');

# %% [markdown]
# #### Random Forest Classifier Method

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(X_train, y_train)

# Predicting train and test(same steps as above)
y_pred_test = model.predict(X_test)
y_pred_train = model.predict(X_train)

# r2_score
rfc_model_train = r2_score(y_train, y_pred_train)
rfc_model_test = r2_score(y_test, y_pred_test)

print(f"R-squared value for train data: {rfc_model_train}")
print(f"R-squared value for test data: {rfc_model_test}")
print(f"Average Missed Distance From Price: {mean_squared_error(y_test, y_pred_test, squared = False)}")
# Out:
# R-squared value for train data: 0.8813234739904247
# R-squared value for test data: 0.1168577949996269
# Average Missed Distance From Price: 48.43207661019832

# %% [markdown]
# #### Random Forest Classifier Visuals

# %%
plt.rcParams['figure.figsize'] = [10, 6]

plt.scatter(y_test, y_pred_test, color = 'black')
plt.title('Scatter Plot Of Random Forest Classifier Result')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price');

# %% [markdown]
# #### Gradient Boosting Regressor Method

# %%
# help - https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingRegressor.html

from sklearn.ensemble import GradientBoostingRegressor
# we will go with the deafult parameters

model = GradientBoostingRegressor()
model.fit(X_train, y_train)

# Predicting train and test(same steps as above)
y_pred_test = model.predict(X_test)
y_pred_train = model.predict(X_train)

# r2_score
gradient_model_train = r2_score(y_train, y_pred_train)
gradient_model_test = r2_score(y_test, y_pred_test)

print(f"R-squared value for train data: {gradient_model_train}")
print(f"R-squared value for test data: {gradient_model_test}")
print(f"Average Missed Distance From Price: {mean_squared_error(y_test, y_pred_test, squared = False)}")
# Out:
# R-squared value for train data: 0.5426674347024945
# R-squared value for test data: 0.47543081495556794
# Average Missed Distance From Price: 37.326662341758166

# %% [markdown]
# #### Gradient Boosting Regressor Visuals

# %%
plt.rcParams['figure.figsize'] = [10, 6]

plt.scatter(y_test, y_pred_test, color = 'black')
plt.title('Scatter Plot Of Gradient Boosting Regressor Result')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price');

# %% [markdown]
# #### Cat Boost Regressor Method

# %%
from catboost import CatBoostRegressor

model = CatBoostRegressor()
model.fit(X_train, y_train)

# Predicting train and test(same steps as above)
y_pred_test = model.predict(X_test)
y_pred_train = model.predict(X_train)

# r2_score
cat_model_train = r2_score(y_train, y_pred_train)
cat_model_test = r2_score(y_test, y_pred_test)
# Out:
# Learning rate set to 0.047321
# 0:	learn: 50.5058642	total: 59.8ms	remaining: 59.8s
# 1:	learn: 49.6381421	total: 62.5ms	remaining: 31.2s
# 2:	learn: 48.8384827	total: 63.4ms	remaining: 21.1s
# 3:	learn: 48.1009007	total: 64.4ms	remaining: 16s
# 4:	learn: 47.3968857	total: 65.2ms	remaining: 13s
# 5:	learn: 46.7251168	total: 66.1ms	remaining: 10.9s
# 6:	learn: 46.1580852	total: 67ms	remaining: 9.51s
# 7:	learn: 45.5826276	total: 67.6ms	remaining: 8.38s
# 8:	learn: 45.0794893	total: 68.6ms	remaining: 7.55s
# 9:	learn: 44.5680349	total: 69.3ms	remaining: 6.86s
# 10:	learn: 44.1039180	total: 70.7ms	remaining: 6.35s
# 11:	learn: 43.6545201	total: 71.4ms	remaining: 5.88s
# 12:	learn: 43.2791719	total: 72.2ms	remaining: 5.48s
# 13:	learn: 42.9242935	total: 73ms	remaining: 5.14s
# 14:	learn: 42.5356967	total: 75.8ms	remaining: 4.97s
# 15:	learn: 42.1884845	total: 76.7ms	remaining: 4.71s
# 16:	learn: 41.8623724	total: 77.4ms	remaining: 4.48s
# 17:	learn: 41.5787551	total: 78.2ms	remaining: 4.26s
# 18:	learn: 41.3125579	total: 78.9ms	remaining: 4.07s
# 19:	learn: 41.0502523	total: 79.6ms	remaining: 3.9s
# 20:	learn: 40.8505795	total: 80.5ms	remaining: 3.75s
# 21:	learn: 40.6193699	total: 81.3ms	remaining: 3.61s
# 22:	learn: 40.4680229	total: 81.9ms	remaining: 3.48s
# 23:	learn: 40.2656696	total: 82.8ms	remaining: 3.37s
# 24:	learn: 40.1112679	total: 83.7ms	remaining: 3.26s
# 25:	learn: 39.9225955	total: 84.4ms	remaining: 3.16s
# 26:	learn: 39.7683097	total: 85.3ms	remaining: 3.07s
# 27:	learn: 39.6233684	total: 86.1ms	remaining: 2.99s
# 28:	learn: 39.4807716	total: 86.9ms	remaining: 2.91s
# 29:	learn: 39.3453141	total: 87.6ms	remaining: 2.83s
# 30:	learn: 39.2377733	total: 89.4ms	remaining: 2.8s
# 31:	learn: 39.1556827	total: 90.3ms	remaining: 2.73s
# 32:	learn: 39.0555028	total: 91ms	remaining: 2.67s
# 33:	learn: 38.9760031	total: 91.7ms	remaining: 2.61s
# 34:	learn: 38.8841091	total: 93.2ms	remaining: 2.57s
# 35:	learn: 38.7861895	total: 93.9ms	remaining: 2.52s
# 36:	learn: 38.6864415	total: 94.7ms	remaining: 2.46s
# 37:	learn: 38.5786879	total: 95.7ms	remaining: 2.42s
# 38:	learn: 38.4921612	total: 96.4ms	remaining: 2.38s
# 39:	learn: 38.3973750	total: 97.3ms	remaining: 2.33s
# 40:	learn: 38.3142943	total: 98.2ms	remaining: 2.3s
# 41:	learn: 38.2445355	total: 99ms	remaining: 2.26s
# 42:	learn: 38.1932544	total: 99.8ms	remaining: 2.22s
# 43:	learn: 38.1348321	total: 100ms	remaining: 2.18s
# 44:	learn: 38.0559097	total: 101ms	remaining: 2.15s
# 45:	learn: 37.9794490	total: 102ms	remaining: 2.12s
# 46:	learn: 37.9084128	total: 104ms	remaining: 2.11s
# 47:	learn: 37.8528232	total: 105ms	remaining: 2.08s
# 48:	learn: 37.7984529	total: 106ms	remaining: 2.06s
# 49:	learn: 37.7501569	total: 107ms	remaining: 2.03s
# 50:	learn: 37.6923433	total: 108ms	remaining: 2s
# 51:	learn: 37.6445328	total: 108ms	remaining: 1.98s
# 52:	learn: 37.5993915	total: 109ms	remaining: 1.95s
# 53:	learn: 37.5703594	total: 110ms	remaining: 1.93s
# 54:	learn: 37.5333536	total: 111ms	remaining: 1.9s
# 55:	learn: 37.4986357	total: 111ms	remaining: 1.88s
# 56:	learn: 37.4646866	total: 112ms	remaining: 1.86s
# 57:	learn: 37.4258003	total: 113ms	remaining: 1.83s
# 58:	learn: 37.3820907	total: 114ms	remaining: 1.81s
# 59:	learn: 37.3450200	total: 115ms	remaining: 1.79s
# 60:	learn: 37.3197855	total: 115ms	remaining: 1.77s
# 61:	learn: 37.2888655	total: 116ms	remaining: 1.75s
# 62:	learn: 37.2574988	total: 117ms	remaining: 1.74s
# 63:	learn: 37.2314109	total: 119ms	remaining: 1.73s
# 64:	learn: 37.1979850	total: 119ms	remaining: 1.72s
# 65:	learn: 37.1708762	total: 120ms	remaining: 1.7s
# 66:	learn: 37.1472760	total: 121ms	remaining: 1.68s
# 67:	learn: 37.1166971	total: 122ms	remaining: 1.67s
# 68:	learn: 37.0784403	total: 123ms	remaining: 1.65s
# 69:	learn: 37.0363970	total: 123ms	remaining: 1.64s
# 70:	learn: 37.0047751	total: 124ms	remaining: 1.62s
# 71:	learn: 36.9746919	total: 125ms	remaining: 1.61s
# 72:	learn: 36.9320554	total: 126ms	remaining: 1.6s
# 73:	learn: 36.9101541	total: 127ms	remaining: 1.58s
# 74:	learn: 36.8911479	total: 127ms	remaining: 1.57s
# 75:	learn: 36.8761510	total: 128ms	remaining: 1.56s
# 76:	learn: 36.8462248	total: 129ms	remaining: 1.54s
# 77:	learn: 36.8222845	total: 130ms	remaining: 1.53s
# 78:	learn: 36.7993066	total: 131ms	remaining: 1.52s
# 79:	learn: 36.7792838	total: 131ms	remaining: 1.51s
# 80:	learn: 36.7434545	total: 134ms	remaining: 1.52s
# 81:	learn: 36.7033230	total: 135ms	remaining: 1.51s
# 82:	learn: 36.6800372	total: 135ms	remaining: 1.5s
# 83:	learn: 36.6365464	total: 136ms	remaining: 1.49s
# 84:	learn: 36.6177630	total: 137ms	remaining: 1.47s
# 85:	learn: 36.5893338	total: 138ms	remaining: 1.46s
# 86:	learn: 36.5502359	total: 138ms	remaining: 1.45s
# 87:	learn: 36.5350449	total: 139ms	remaining: 1.44s
# 88:	learn: 36.5201083	total: 140ms	remaining: 1.43s
# 89:	learn: 36.5049285	total: 141ms	remaining: 1.42s
# 90:	learn: 36.4786401	total: 141ms	remaining: 1.41s
# 91:	learn: 36.4402695	total: 142ms	remaining: 1.4s
# 92:	learn: 36.4248002	total: 143ms	remaining: 1.39s
# 93:	learn: 36.4077597	total: 144ms	remaining: 1.38s
# 94:	learn: 36.3897297	total: 144ms	remaining: 1.38s
# 95:	learn: 36.3765014	total: 145ms	remaining: 1.37s
# 96:	learn: 36.3617023	total: 146ms	remaining: 1.36s
# 97:	learn: 36.3314946	total: 147ms	remaining: 1.35s
# 98:	learn: 36.3067874	total: 148ms	remaining: 1.34s
# 99:	learn: 36.2853874	total: 149ms	remaining: 1.34s
# 100:	learn: 36.2630136	total: 149ms	remaining: 1.33s
# 101:	learn: 36.2489263	total: 150ms	remaining: 1.32s
# 102:	learn: 36.2243755	total: 151ms	remaining: 1.31s
# 103:	learn: 36.2072593	total: 152ms	remaining: 1.3s
# 104:	learn: 36.1990296	total: 152ms	remaining: 1.3s
# 105:	learn: 36.1807009	total: 153ms	remaining: 1.29s
# 106:	learn: 36.1726827	total: 154ms	remaining: 1.28s
# 107:	learn: 36.1629834	total: 155ms	remaining: 1.28s
# 108:	learn: 36.1505683	total: 155ms	remaining: 1.27s
# 109:	learn: 36.1347927	total: 156ms	remaining: 1.26s
# 110:	learn: 36.1019401	total: 157ms	remaining: 1.26s
# 111:	learn: 36.0831629	total: 158ms	remaining: 1.25s
# 112:	learn: 36.0606900	total: 159ms	remaining: 1.25s
# 113:	learn: 36.0444748	total: 160ms	remaining: 1.24s
# 114:	learn: 36.0307169	total: 163ms	remaining: 1.25s
# 115:	learn: 36.0223201	total: 164ms	remaining: 1.25s
# 116:	learn: 35.9983423	total: 165ms	remaining: 1.25s
# 117:	learn: 35.9882039	total: 166ms	remaining: 1.24s
# 118:	learn: 35.9560898	total: 169ms	remaining: 1.25s
# 119:	learn: 35.9303829	total: 170ms	remaining: 1.24s
# 120:	learn: 35.9130141	total: 171ms	remaining: 1.24s
# 121:	learn: 35.9052112	total: 172ms	remaining: 1.24s
# 122:	learn: 35.9033698	total: 173ms	remaining: 1.23s
# 123:	learn: 35.8706005	total: 174ms	remaining: 1.23s
# 124:	learn: 35.8473774	total: 178ms	remaining: 1.25s
# 125:	learn: 35.8174511	total: 179ms	remaining: 1.24s
# 126:	learn: 35.7976614	total: 180ms	remaining: 1.23s
# 127:	learn: 35.7576831	total: 181ms	remaining: 1.23s
# 128:	learn: 35.7501779	total: 183ms	remaining: 1.23s
# 129:	learn: 35.7307956	total: 183ms	remaining: 1.23s
# 130:	learn: 35.7182903	total: 184ms	remaining: 1.22s
# 131:	learn: 35.6885480	total: 185ms	remaining: 1.22s
# 132:	learn: 35.6786537	total: 186ms	remaining: 1.21s
# 133:	learn: 35.6601476	total: 187ms	remaining: 1.21s
# 134:	learn: 35.6387126	total: 187ms	remaining: 1.2s
# 135:	learn: 35.6341906	total: 188ms	remaining: 1.19s
# 136:	learn: 35.6272875	total: 189ms	remaining: 1.19s
# 137:	learn: 35.6134127	total: 190ms	remaining: 1.19s
# 138:	learn: 35.5904114	total: 191ms	remaining: 1.18s
# 139:	learn: 35.5659684	total: 192ms	remaining: 1.18s
# 140:	learn: 35.5418021	total: 193ms	remaining: 1.18s
# 141:	learn: 35.5168298	total: 194ms	remaining: 1.17s
# 142:	learn: 35.5083937	total: 195ms	remaining: 1.17s
# 143:	learn: 35.4934255	total: 195ms	remaining: 1.16s
# 144:	learn: 35.4686792	total: 196ms	remaining: 1.16s
# 145:	learn: 35.4484168	total: 197ms	remaining: 1.15s
# 146:	learn: 35.4291528	total: 198ms	remaining: 1.15s
# 147:	learn: 35.4124602	total: 199ms	remaining: 1.14s
# 148:	learn: 35.3944105	total: 199ms	remaining: 1.14s
# 149:	learn: 35.3877184	total: 200ms	remaining: 1.13s
# 150:	learn: 35.3738673	total: 201ms	remaining: 1.13s
# 151:	learn: 35.3659955	total: 204ms	remaining: 1.14s
# 152:	learn: 35.3541829	total: 205ms	remaining: 1.13s
# 153:	learn: 35.3481115	total: 206ms	remaining: 1.13s
# 154:	learn: 35.3221992	total: 207ms	remaining: 1.13s
# 155:	learn: 35.3028296	total: 208ms	remaining: 1.12s
# 156:	learn: 35.2703641	total: 209ms	remaining: 1.12s
# 157:	learn: 35.2543936	total: 209ms	remaining: 1.11s
# 158:	learn: 35.2203363	total: 210ms	remaining: 1.11s
# 159:	learn: 35.2108313	total: 211ms	remaining: 1.11s
# 160:	learn: 35.1903965	total: 212ms	remaining: 1.1s
# 161:	learn: 35.1765147	total: 213ms	remaining: 1.1s
# 162:	learn: 35.1600953	total: 214ms	remaining: 1.1s
# 163:	learn: 35.1441688	total: 215ms	remaining: 1.1s
# 164:	learn: 35.1108958	total: 218ms	remaining: 1.1s
# 165:	learn: 35.0927043	total: 218ms	remaining: 1.1s
# 166:	learn: 35.0792384	total: 219ms	remaining: 1.09s
# 167:	learn: 35.0647864	total: 220ms	remaining: 1.09s
# 168:	learn: 35.0566000	total: 221ms	remaining: 1.08s
# 169:	learn: 35.0313308	total: 221ms	remaining: 1.08s
# 170:	learn: 35.0254970	total: 222ms	remaining: 1.08s
# 171:	learn: 35.0177013	total: 223ms	remaining: 1.07s
# 172:	learn: 35.0075135	total: 224ms	remaining: 1.07s
# 173:	learn: 34.9820788	total: 225ms	remaining: 1.07s
# 174:	learn: 34.9629710	total: 225ms	remaining: 1.06s
# 175:	learn: 34.9469933	total: 226ms	remaining: 1.06s
# 176:	learn: 34.9305305	total: 227ms	remaining: 1.05s
# 177:	learn: 34.9176855	total: 228ms	remaining: 1.05s
# 178:	learn: 34.9079540	total: 229ms	remaining: 1.05s
# 179:	learn: 34.8947844	total: 229ms	remaining: 1.04s
# 180:	learn: 34.8787236	total: 230ms	remaining: 1.04s
# 181:	learn: 34.8682350	total: 232ms	remaining: 1.04s
# 182:	learn: 34.8348719	total: 233ms	remaining: 1.04s
# 183:	learn: 34.8230799	total: 234ms	remaining: 1.04s
# 184:	learn: 34.8011305	total: 235ms	remaining: 1.03s
# 185:	learn: 34.7925915	total: 235ms	remaining: 1.03s
# 186:	learn: 34.7757320	total: 236ms	remaining: 1.03s
# 187:	learn: 34.7502472	total: 237ms	remaining: 1.02s
# 188:	learn: 34.7462541	total: 238ms	remaining: 1.02s
# 189:	learn: 34.7259123	total: 238ms	remaining: 1.01s
# 190:	learn: 34.6923262	total: 239ms	remaining: 1.01s
# 191:	learn: 34.6765569	total: 240ms	remaining: 1.01s
# 192:	learn: 34.6515209	total: 240ms	remaining: 1s
# 193:	learn: 34.6413421	total: 241ms	remaining: 1s
# 194:	learn: 34.6176942	total: 242ms	remaining: 998ms
# 195:	learn: 34.6092652	total: 243ms	remaining: 995ms
# 196:	learn: 34.5917660	total: 243ms	remaining: 992ms
# 197:	learn: 34.5799727	total: 244ms	remaining: 989ms
# 198:	learn: 34.5753484	total: 245ms	remaining: 986ms
# 199:	learn: 34.5566909	total: 247ms	remaining: 987ms
# 200:	learn: 34.5443363	total: 248ms	remaining: 985ms
# 201:	learn: 34.5242635	total: 249ms	remaining: 982ms
# 202:	learn: 34.5160126	total: 249ms	remaining: 979ms
# 203:	learn: 34.5032694	total: 250ms	remaining: 976ms
# 204:	learn: 34.4861734	total: 251ms	remaining: 973ms
# 205:	learn: 34.4467971	total: 252ms	remaining: 970ms
# 206:	learn: 34.4255652	total: 252ms	remaining: 967ms
# 207:	learn: 34.4228360	total: 253ms	remaining: 963ms
# 208:	learn: 34.4172918	total: 254ms	remaining: 961ms
# 209:	learn: 34.3999611	total: 255ms	remaining: 958ms
# 210:	learn: 34.3974327	total: 255ms	remaining: 954ms
# 211:	learn: 34.3719487	total: 256ms	remaining: 952ms
# 212:	learn: 34.3689139	total: 257ms	remaining: 949ms
# 213:	learn: 34.3410907	total: 258ms	remaining: 946ms
# 214:	learn: 34.3317013	total: 258ms	remaining: 943ms
# 215:	learn: 34.3133749	total: 259ms	remaining: 941ms
# 216:	learn: 34.3097679	total: 261ms	remaining: 943ms
# 217:	learn: 34.2911668	total: 262ms	remaining: 940ms
# 218:	learn: 34.2743820	total: 263ms	remaining: 938ms
# 219:	learn: 34.2567313	total: 264ms	remaining: 935ms
# 220:	learn: 34.2365493	total: 265ms	remaining: 933ms
# 221:	learn: 34.2066884	total: 265ms	remaining: 930ms
# 222:	learn: 34.2004076	total: 266ms	remaining: 927ms
# 223:	learn: 34.1656569	total: 267ms	remaining: 925ms
# 224:	learn: 34.1471204	total: 268ms	remaining: 922ms
# 225:	learn: 34.1182838	total: 268ms	remaining: 919ms
# 226:	learn: 34.1038647	total: 269ms	remaining: 917ms
# 227:	learn: 34.0849097	total: 270ms	remaining: 914ms
# 228:	learn: 34.0818870	total: 271ms	remaining: 911ms
# 229:	learn: 34.0645030	total: 271ms	remaining: 909ms
# 230:	learn: 34.0318622	total: 272ms	remaining: 906ms
# 231:	learn: 34.0294815	total: 273ms	remaining: 904ms
# 232:	learn: 34.0263894	total: 274ms	remaining: 901ms
# 233:	learn: 34.0095216	total: 275ms	remaining: 899ms
# 234:	learn: 33.9982949	total: 276ms	remaining: 900ms
# 235:	learn: 33.9847787	total: 277ms	remaining: 898ms
# 236:	learn: 33.9701826	total: 278ms	remaining: 896ms
# 237:	learn: 33.9676452	total: 279ms	remaining: 893ms
# 238:	learn: 33.9652958	total: 280ms	remaining: 891ms
# 239:	learn: 33.9394918	total: 281ms	remaining: 888ms
# 240:	learn: 33.9149930	total: 281ms	remaining: 886ms
# 241:	learn: 33.8976269	total: 282ms	remaining: 884ms
# 242:	learn: 33.8907800	total: 283ms	remaining: 881ms
# 243:	learn: 33.8738580	total: 284ms	remaining: 879ms
# 244:	learn: 33.8710470	total: 284ms	remaining: 876ms
# 245:	learn: 33.8463147	total: 285ms	remaining: 874ms
# 246:	learn: 33.8201857	total: 286ms	remaining: 872ms
# 247:	learn: 33.8042189	total: 287ms	remaining: 870ms
# 248:	learn: 33.7893432	total: 288ms	remaining: 867ms
# 249:	learn: 33.7762960	total: 288ms	remaining: 865ms
# 250:	learn: 33.7580185	total: 289ms	remaining: 863ms
# 251:	learn: 33.7441363	total: 291ms	remaining: 865ms
# 252:	learn: 33.7410645	total: 292ms	remaining: 863ms
# 253:	learn: 33.7308093	total: 293ms	remaining: 861ms
# 254:	learn: 33.7198531	total: 294ms	remaining: 859ms
# 255:	learn: 33.6940819	total: 295ms	remaining: 857ms
# 256:	learn: 33.6736001	total: 296ms	remaining: 855ms
# 257:	learn: 33.6706488	total: 296ms	remaining: 852ms
# 258:	learn: 33.6638906	total: 297ms	remaining: 850ms
# 259:	learn: 33.6609721	total: 298ms	remaining: 848ms
# 260:	learn: 33.6381416	total: 299ms	remaining: 846ms
# 261:	learn: 33.6279447	total: 299ms	remaining: 843ms
# 262:	learn: 33.6256764	total: 300ms	remaining: 841ms
# 263:	learn: 33.6051730	total: 301ms	remaining: 839ms
# 264:	learn: 33.5965981	total: 302ms	remaining: 837ms
# 265:	learn: 33.5816861	total: 302ms	remaining: 834ms
# 266:	learn: 33.5677991	total: 303ms	remaining: 832ms
# 267:	learn: 33.5654693	total: 304ms	remaining: 830ms
# 268:	learn: 33.5632150	total: 305ms	remaining: 828ms
# 269:	learn: 33.5508040	total: 306ms	remaining: 826ms
# 270:	learn: 33.5487046	total: 306ms	remaining: 824ms
# 271:	learn: 33.5423887	total: 307ms	remaining: 822ms
# 272:	learn: 33.5276991	total: 308ms	remaining: 820ms
# 273:	learn: 33.5126484	total: 309ms	remaining: 818ms
# 274:	learn: 33.4824011	total: 310ms	remaining: 816ms
# 275:	learn: 33.4696118	total: 310ms	remaining: 814ms
# 276:	learn: 33.4675044	total: 311ms	remaining: 812ms
# 277:	learn: 33.4443826	total: 312ms	remaining: 810ms
# 278:	learn: 33.4298712	total: 313ms	remaining: 808ms
# 279:	learn: 33.4130534	total: 313ms	remaining: 806ms
# 280:	learn: 33.3950976	total: 314ms	remaining: 804ms
# 281:	learn: 33.3914352	total: 315ms	remaining: 802ms
# 282:	learn: 33.3889557	total: 316ms	remaining: 800ms
# 283:	learn: 33.3708103	total: 317ms	remaining: 798ms
# 284:	learn: 33.3373087	total: 317ms	remaining: 796ms
# 285:	learn: 33.3314280	total: 320ms	remaining: 798ms
# 286:	learn: 33.3179094	total: 321ms	remaining: 796ms
# 287:	learn: 33.3033596	total: 321ms	remaining: 794ms
# 288:	learn: 33.2939300	total: 322ms	remaining: 792ms
# 289:	learn: 33.2919971	total: 323ms	remaining: 790ms
# 290:	learn: 33.2728021	total: 323ms	remaining: 788ms
# 291:	learn: 33.2565053	total: 324ms	remaining: 786ms
# 292:	learn: 33.2387908	total: 325ms	remaining: 784ms
# 293:	learn: 33.2318011	total: 326ms	remaining: 782ms
# 294:	learn: 33.2299472	total: 327ms	remaining: 780ms
# 295:	learn: 33.2281611	total: 327ms	remaining: 778ms
# 296:	learn: 33.2181532	total: 328ms	remaining: 776ms
# 297:	learn: 33.2074877	total: 329ms	remaining: 774ms
# 298:	learn: 33.1995751	total: 329ms	remaining: 772ms
# 299:	learn: 33.1981207	total: 330ms	remaining: 770ms
# 300:	learn: 33.1856338	total: 331ms	remaining: 768ms
# 301:	learn: 33.1789662	total: 331ms	remaining: 766ms
# 302:	learn: 33.1768906	total: 332ms	remaining: 764ms
# 303:	learn: 33.1571678	total: 333ms	remaining: 762ms
# 304:	learn: 33.1554527	total: 334ms	remaining: 760ms
# 305:	learn: 33.1220538	total: 335ms	remaining: 760ms
# 306:	learn: 33.1050867	total: 336ms	remaining: 758ms
# 307:	learn: 33.0904275	total: 336ms	remaining: 756ms
# 308:	learn: 33.0810709	total: 337ms	remaining: 754ms
# 309:	learn: 33.0732128	total: 338ms	remaining: 752ms
# 310:	learn: 33.0602476	total: 339ms	remaining: 750ms
# 311:	learn: 33.0585747	total: 339ms	remaining: 748ms
# 312:	learn: 33.0458459	total: 340ms	remaining: 747ms
# 313:	learn: 33.0184804	total: 341ms	remaining: 746ms
# 314:	learn: 33.0162162	total: 342ms	remaining: 745ms
# 315:	learn: 33.0147152	total: 343ms	remaining: 743ms
# 316:	learn: 33.0057598	total: 344ms	remaining: 741ms
# 317:	learn: 32.9946957	total: 345ms	remaining: 739ms
# 318:	learn: 32.9804148	total: 345ms	remaining: 737ms
# 319:	learn: 32.9784419	total: 346ms	remaining: 736ms
# 320:	learn: 32.9631664	total: 347ms	remaining: 734ms
# 321:	learn: 32.9569095	total: 348ms	remaining: 732ms
# 322:	learn: 32.9553808	total: 352ms	remaining: 738ms
# 323:	learn: 32.9471440	total: 353ms	remaining: 736ms
# 324:	learn: 32.9456685	total: 354ms	remaining: 734ms
# 325:	learn: 32.9438871	total: 355ms	remaining: 734ms
# 326:	learn: 32.9423957	total: 356ms	remaining: 733ms
# 327:	learn: 32.9411221	total: 357ms	remaining: 732ms
# 328:	learn: 32.9355246	total: 358ms	remaining: 730ms
# 329:	learn: 32.9342937	total: 359ms	remaining: 728ms
# 330:	learn: 32.9290828	total: 360ms	remaining: 727ms
# 331:	learn: 32.9094656	total: 360ms	remaining: 725ms
# 332:	learn: 32.9081623	total: 361ms	remaining: 723ms
# 333:	learn: 32.9068914	total: 362ms	remaining: 722ms
# 334:	learn: 32.8999483	total: 363ms	remaining: 721ms
# 335:	learn: 32.8979329	total: 365ms	remaining: 721ms
# 336:	learn: 32.8740121	total: 366ms	remaining: 720ms
# 337:	learn: 32.8727817	total: 368ms	remaining: 720ms
# 338:	learn: 32.8605033	total: 368ms	remaining: 718ms
# 339:	learn: 32.8487909	total: 369ms	remaining: 717ms
# 340:	learn: 32.8463528	total: 370ms	remaining: 715ms
# 341:	learn: 32.8386371	total: 371ms	remaining: 714ms
# 342:	learn: 32.8229799	total: 372ms	remaining: 713ms
# 343:	learn: 32.8074322	total: 373ms	remaining: 711ms
# 344:	learn: 32.7905090	total: 374ms	remaining: 710ms
# 345:	learn: 32.7639627	total: 375ms	remaining: 709ms
# 346:	learn: 32.7580156	total: 376ms	remaining: 707ms
# 347:	learn: 32.7480250	total: 376ms	remaining: 705ms
# 348:	learn: 32.7317763	total: 378ms	remaining: 705ms
# 349:	learn: 32.7188437	total: 379ms	remaining: 704ms
# 350:	learn: 32.7177017	total: 381ms	remaining: 704ms
# 351:	learn: 32.7028934	total: 382ms	remaining: 703ms
# 352:	learn: 32.6965916	total: 382ms	remaining: 701ms
# 353:	learn: 32.6947029	total: 383ms	remaining: 699ms
# 354:	learn: 32.6800903	total: 384ms	remaining: 697ms
# 355:	learn: 32.6790585	total: 385ms	remaining: 696ms
# 356:	learn: 32.6642303	total: 386ms	remaining: 694ms
# 357:	learn: 32.6489201	total: 386ms	remaining: 693ms
# 358:	learn: 32.6296391	total: 387ms	remaining: 692ms
# 359:	learn: 32.6262264	total: 388ms	remaining: 690ms
# 360:	learn: 32.6207100	total: 389ms	remaining: 688ms
# 361:	learn: 32.6103200	total: 390ms	remaining: 687ms
# 362:	learn: 32.6092242	total: 390ms	remaining: 685ms
# 363:	learn: 32.5982145	total: 391ms	remaining: 683ms
# 364:	learn: 32.5972955	total: 392ms	remaining: 681ms
# 365:	learn: 32.5907226	total: 394ms	remaining: 682ms
# 366:	learn: 32.5889598	total: 395ms	remaining: 681ms
# 367:	learn: 32.5873343	total: 396ms	remaining: 679ms
# 368:	learn: 32.5629113	total: 396ms	remaining: 678ms
# 369:	learn: 32.5423689	total: 397ms	remaining: 676ms
# 370:	learn: 32.5353059	total: 398ms	remaining: 674ms
# 371:	learn: 32.5196201	total: 398ms	remaining: 673ms
# 372:	learn: 32.5180495	total: 399ms	remaining: 671ms
# 373:	learn: 32.5053837	total: 400ms	remaining: 670ms
# 374:	learn: 32.4902944	total: 401ms	remaining: 668ms
# 375:	learn: 32.4789111	total: 402ms	remaining: 667ms
# 376:	learn: 32.4689661	total: 403ms	remaining: 665ms
# 377:	learn: 32.4658171	total: 403ms	remaining: 664ms
# 378:	learn: 32.4607253	total: 404ms	remaining: 662ms
# 379:	learn: 32.4468714	total: 405ms	remaining: 661ms
# 380:	learn: 32.4407985	total: 406ms	remaining: 659ms
# 381:	learn: 32.4272387	total: 406ms	remaining: 657ms
# 382:	learn: 32.4121648	total: 408ms	remaining: 658ms
# 383:	learn: 32.4060931	total: 410ms	remaining: 657ms
# 384:	learn: 32.3824936	total: 410ms	remaining: 656ms
# 385:	learn: 32.3664850	total: 411ms	remaining: 654ms
# 386:	learn: 32.3579591	total: 412ms	remaining: 652ms
# 387:	learn: 32.3519537	total: 413ms	remaining: 651ms
# 388:	learn: 32.3354060	total: 413ms	remaining: 649ms
# 389:	learn: 32.3345873	total: 414ms	remaining: 648ms
# 390:	learn: 32.3337830	total: 415ms	remaining: 646ms
# 391:	learn: 32.3221560	total: 416ms	remaining: 645ms
# 392:	learn: 32.3080152	total: 417ms	remaining: 644ms
# 393:	learn: 32.3071968	total: 418ms	remaining: 642ms
# 394:	learn: 32.2950335	total: 418ms	remaining: 641ms
# 395:	learn: 32.2936509	total: 419ms	remaining: 639ms
# 396:	learn: 32.2806654	total: 420ms	remaining: 638ms
# 397:	learn: 32.2796240	total: 420ms	remaining: 636ms
# 398:	learn: 32.2674304	total: 422ms	remaining: 635ms
# 399:	learn: 32.2666417	total: 422ms	remaining: 634ms
# 400:	learn: 32.2591206	total: 423ms	remaining: 633ms
# 401:	learn: 32.2438350	total: 425ms	remaining: 632ms
# 402:	learn: 32.2285428	total: 425ms	remaining: 630ms
# 403:	learn: 32.2277730	total: 426ms	remaining: 629ms
# 404:	learn: 32.2136355	total: 427ms	remaining: 627ms
# 405:	learn: 32.2128833	total: 428ms	remaining: 626ms
# 406:	learn: 32.2066391	total: 429ms	remaining: 625ms
# 407:	learn: 32.1956935	total: 430ms	remaining: 623ms
# 408:	learn: 32.1864594	total: 430ms	remaining: 622ms
# 409:	learn: 32.1752204	total: 431ms	remaining: 620ms
# 410:	learn: 32.1640222	total: 432ms	remaining: 619ms
# 411:	learn: 32.1526211	total: 433ms	remaining: 617ms
# 412:	learn: 32.1429186	total: 433ms	remaining: 616ms
# 413:	learn: 32.1276397	total: 434ms	remaining: 614ms
# 414:	learn: 32.1202150	total: 436ms	remaining: 615ms
# 415:	learn: 32.1112687	total: 437ms	remaining: 614ms
# 416:	learn: 32.1023564	total: 438ms	remaining: 613ms
# 417:	learn: 32.0935413	total: 439ms	remaining: 611ms
# 418:	learn: 32.0920399	total: 440ms	remaining: 610ms
# 419:	learn: 32.0855945	total: 440ms	remaining: 608ms
# 420:	learn: 32.0747439	total: 441ms	remaining: 606ms
# 421:	learn: 32.0653571	total: 442ms	remaining: 605ms
# 422:	learn: 32.0522063	total: 443ms	remaining: 604ms
# 423:	learn: 32.0324636	total: 444ms	remaining: 603ms
# 424:	learn: 32.0197981	total: 444ms	remaining: 601ms
# 425:	learn: 32.0158021	total: 445ms	remaining: 600ms
# 426:	learn: 32.0012917	total: 446ms	remaining: 599ms
# 427:	learn: 31.9974198	total: 447ms	remaining: 597ms
# 428:	learn: 31.9961753	total: 447ms	remaining: 595ms
# 429:	learn: 31.9833499	total: 448ms	remaining: 594ms
# 430:	learn: 31.9825128	total: 450ms	remaining: 595ms
# 431:	learn: 31.9813331	total: 451ms	remaining: 593ms
# 432:	learn: 31.9763913	total: 453ms	remaining: 594ms
# 433:	learn: 31.9631526	total: 454ms	remaining: 592ms
# 434:	learn: 31.9578595	total: 455ms	remaining: 591ms
# 435:	learn: 31.9506011	total: 455ms	remaining: 589ms
# 436:	learn: 31.9341903	total: 456ms	remaining: 588ms
# 437:	learn: 31.9081072	total: 457ms	remaining: 587ms
# 438:	learn: 31.9074035	total: 458ms	remaining: 585ms
# 439:	learn: 31.8988638	total: 459ms	remaining: 584ms
# 440:	learn: 31.8851732	total: 460ms	remaining: 583ms
# 441:	learn: 31.8843029	total: 460ms	remaining: 581ms
# 442:	learn: 31.8731498	total: 461ms	remaining: 580ms
# 443:	learn: 31.8563532	total: 462ms	remaining: 578ms
# 444:	learn: 31.8466191	total: 463ms	remaining: 577ms
# 445:	learn: 31.8423707	total: 464ms	remaining: 576ms
# 446:	learn: 31.8409853	total: 464ms	remaining: 575ms
# 447:	learn: 31.8403215	total: 466ms	remaining: 574ms
# 448:	learn: 31.8268329	total: 467ms	remaining: 573ms
# 449:	learn: 31.8139353	total: 468ms	remaining: 572ms
# 450:	learn: 31.7981057	total: 469ms	remaining: 571ms
# 451:	learn: 31.7909738	total: 469ms	remaining: 569ms
# 452:	learn: 31.7846569	total: 470ms	remaining: 567ms
# 453:	learn: 31.7775664	total: 471ms	remaining: 566ms
# 454:	learn: 31.7703970	total: 472ms	remaining: 565ms
# 455:	learn: 31.7627384	total: 472ms	remaining: 564ms
# 456:	learn: 31.7540809	total: 473ms	remaining: 562ms
# 457:	learn: 31.7534357	total: 474ms	remaining: 561ms
# 458:	learn: 31.7507303	total: 475ms	remaining: 559ms
# 459:	learn: 31.7436085	total: 475ms	remaining: 558ms
# 460:	learn: 31.7427684	total: 476ms	remaining: 557ms
# 461:	learn: 31.7230470	total: 477ms	remaining: 555ms
# 462:	learn: 31.7152097	total: 478ms	remaining: 554ms
# 463:	learn: 31.7087306	total: 479ms	remaining: 553ms
# 464:	learn: 31.6855154	total: 479ms	remaining: 551ms
# 465:	learn: 31.6783678	total: 481ms	remaining: 552ms
# 466:	learn: 31.6716232	total: 482ms	remaining: 550ms
# 467:	learn: 31.6704890	total: 483ms	remaining: 549ms
# 468:	learn: 31.6625662	total: 483ms	remaining: 547ms
# 469:	learn: 31.6527294	total: 484ms	remaining: 546ms
# 470:	learn: 31.6373283	total: 485ms	remaining: 545ms
# 471:	learn: 31.6362069	total: 486ms	remaining: 543ms
# 472:	learn: 31.6327067	total: 486ms	remaining: 542ms
# 473:	learn: 31.6203669	total: 487ms	remaining: 540ms
# 474:	learn: 31.6012231	total: 488ms	remaining: 539ms
# 475:	learn: 31.5925237	total: 488ms	remaining: 538ms
# 476:	learn: 31.5866190	total: 489ms	remaining: 537ms
# 477:	learn: 31.5822324	total: 490ms	remaining: 535ms
# 478:	learn: 31.5810284	total: 491ms	remaining: 534ms
# 479:	learn: 31.5740508	total: 492ms	remaining: 533ms
# 480:	learn: 31.5675731	total: 492ms	remaining: 531ms
# 481:	learn: 31.5597611	total: 493ms	remaining: 530ms
# 482:	learn: 31.5463900	total: 494ms	remaining: 528ms
# 483:	learn: 31.5433671	total: 495ms	remaining: 528ms
# 484:	learn: 31.5403712	total: 496ms	remaining: 527ms
# 485:	learn: 31.5256507	total: 497ms	remaining: 526ms
# 486:	learn: 31.5133706	total: 498ms	remaining: 524ms
# 487:	learn: 31.5126502	total: 499ms	remaining: 523ms
# 488:	learn: 31.4987036	total: 500ms	remaining: 522ms
# 489:	learn: 31.4975382	total: 500ms	remaining: 521ms
# 490:	learn: 31.4886033	total: 501ms	remaining: 519ms
# 491:	learn: 31.4717958	total: 502ms	remaining: 518ms
# 492:	learn: 31.4626571	total: 502ms	remaining: 517ms
# 493:	learn: 31.4487438	total: 503ms	remaining: 516ms
# 494:	learn: 31.4436064	total: 504ms	remaining: 514ms
# 495:	learn: 31.4354075	total: 505ms	remaining: 513ms
# 496:	learn: 31.4292830	total: 507ms	remaining: 513ms
# 497:	learn: 31.4191364	total: 508ms	remaining: 512ms
# 498:	learn: 31.4031941	total: 508ms	remaining: 510ms
# 499:	learn: 31.4001634	total: 510ms	remaining: 510ms
# 500:	learn: 31.3940868	total: 511ms	remaining: 509ms
# 501:	learn: 31.3883802	total: 512ms	remaining: 507ms
# 502:	learn: 31.3850385	total: 513ms	remaining: 506ms
# 503:	learn: 31.3676650	total: 514ms	remaining: 505ms
# 504:	learn: 31.3497640	total: 514ms	remaining: 504ms
# 505:	learn: 31.3490643	total: 515ms	remaining: 503ms
# 506:	learn: 31.3461373	total: 516ms	remaining: 501ms
# 507:	learn: 31.3379724	total: 516ms	remaining: 500ms
# 508:	learn: 31.3305558	total: 518ms	remaining: 500ms
# 509:	learn: 31.3296273	total: 519ms	remaining: 499ms
# 510:	learn: 31.3262027	total: 521ms	remaining: 499ms
# 511:	learn: 31.3188261	total: 522ms	remaining: 497ms
# 512:	learn: 31.3025516	total: 523ms	remaining: 496ms
# 513:	learn: 31.2960261	total: 523ms	remaining: 495ms
# 514:	learn: 31.2906592	total: 524ms	remaining: 493ms
# 515:	learn: 31.2751630	total: 528ms	remaining: 495ms
# 516:	learn: 31.2694233	total: 529ms	remaining: 494ms
# 517:	learn: 31.2559623	total: 530ms	remaining: 493ms
# 518:	learn: 31.2504548	total: 531ms	remaining: 492ms
# 519:	learn: 31.2436264	total: 532ms	remaining: 491ms
# 520:	learn: 31.2360840	total: 532ms	remaining: 489ms
# 521:	learn: 31.2252480	total: 533ms	remaining: 488ms
# 522:	learn: 31.2211608	total: 534ms	remaining: 487ms
# 523:	learn: 31.2133323	total: 535ms	remaining: 486ms
# 524:	learn: 31.2125169	total: 535ms	remaining: 484ms
# 525:	learn: 31.2117517	total: 536ms	remaining: 483ms
# 526:	learn: 31.2108124	total: 537ms	remaining: 482ms
# 527:	learn: 31.1959284	total: 537ms	remaining: 480ms
# 528:	learn: 31.1796697	total: 538ms	remaining: 479ms
# 529:	learn: 31.1788437	total: 540ms	remaining: 479ms
# 530:	learn: 31.1749743	total: 540ms	remaining: 477ms
# 531:	learn: 31.1673313	total: 542ms	remaining: 476ms
# 532:	learn: 31.1648527	total: 543ms	remaining: 476ms
# 533:	learn: 31.1619015	total: 543ms	remaining: 474ms
# 534:	learn: 31.1405656	total: 544ms	remaining: 473ms
# 535:	learn: 31.1340233	total: 545ms	remaining: 471ms
# 536:	learn: 31.1273424	total: 545ms	remaining: 470ms
# 537:	learn: 31.1185528	total: 546ms	remaining: 469ms
# 538:	learn: 31.1159886	total: 547ms	remaining: 468ms
# 539:	learn: 31.1082120	total: 548ms	remaining: 467ms
# 540:	learn: 31.1021901	total: 549ms	remaining: 465ms
# 541:	learn: 31.0996299	total: 549ms	remaining: 464ms
# 542:	learn: 31.0990707	total: 550ms	remaining: 463ms
# 543:	learn: 31.0937406	total: 551ms	remaining: 462ms
# 544:	learn: 31.0833817	total: 551ms	remaining: 460ms
# 545:	learn: 31.0811164	total: 552ms	remaining: 459ms
# 546:	learn: 31.0624968	total: 552ms	remaining: 458ms
# 547:	learn: 31.0561949	total: 554ms	remaining: 457ms
# 548:	learn: 31.0494397	total: 555ms	remaining: 456ms
# 549:	learn: 31.0487215	total: 555ms	remaining: 454ms
# 550:	learn: 31.0389144	total: 556ms	remaining: 453ms
# 551:	learn: 31.0307675	total: 557ms	remaining: 452ms
# 552:	learn: 31.0252868	total: 558ms	remaining: 451ms
# 553:	learn: 31.0160126	total: 558ms	remaining: 450ms
# 554:	learn: 31.0102904	total: 559ms	remaining: 448ms
# 555:	learn: 30.9943429	total: 560ms	remaining: 447ms
# 556:	learn: 30.9846901	total: 560ms	remaining: 446ms
# 557:	learn: 30.9839846	total: 561ms	remaining: 444ms
# 558:	learn: 30.9642004	total: 562ms	remaining: 443ms
# 559:	learn: 30.9635143	total: 563ms	remaining: 442ms
# 560:	learn: 30.9594520	total: 563ms	remaining: 441ms
# 561:	learn: 30.9569165	total: 564ms	remaining: 439ms
# 562:	learn: 30.9437580	total: 564ms	remaining: 438ms
# 563:	learn: 30.9368959	total: 565ms	remaining: 437ms
# 564:	learn: 30.9238391	total: 566ms	remaining: 436ms
# 565:	learn: 30.9186508	total: 567ms	remaining: 434ms
# 566:	learn: 30.9144196	total: 567ms	remaining: 433ms
# 567:	learn: 30.9100307	total: 569ms	remaining: 432ms
# 568:	learn: 30.9069771	total: 570ms	remaining: 432ms
# 569:	learn: 30.8963773	total: 571ms	remaining: 431ms
# 570:	learn: 30.8933898	total: 572ms	remaining: 430ms
# 571:	learn: 30.8910268	total: 573ms	remaining: 429ms
# 572:	learn: 30.8904750	total: 574ms	remaining: 427ms
# 573:	learn: 30.8827812	total: 574ms	remaining: 426ms
# 574:	learn: 30.8753474	total: 575ms	remaining: 425ms
# 575:	learn: 30.8684652	total: 575ms	remaining: 424ms
# 576:	learn: 30.8545126	total: 576ms	remaining: 422ms
# 577:	learn: 30.8535974	total: 577ms	remaining: 421ms
# 578:	learn: 30.8455631	total: 578ms	remaining: 420ms
# 579:	learn: 30.8432862	total: 579ms	remaining: 419ms
# 580:	learn: 30.8363853	total: 579ms	remaining: 418ms
# 581:	learn: 30.8322757	total: 580ms	remaining: 417ms
# 582:	learn: 30.8220638	total: 581ms	remaining: 415ms
# 583:	learn: 30.8166345	total: 581ms	remaining: 414ms
# 584:	learn: 30.8128003	total: 582ms	remaining: 413ms
# 585:	learn: 30.8083331	total: 583ms	remaining: 412ms
# 586:	learn: 30.8062543	total: 583ms	remaining: 410ms
# 587:	learn: 30.7964297	total: 586ms	remaining: 410ms
# 588:	learn: 30.7956953	total: 586ms	remaining: 409ms
# 589:	learn: 30.7951213	total: 587ms	remaining: 408ms
# 590:	learn: 30.7839856	total: 588ms	remaining: 407ms
# 591:	learn: 30.7705617	total: 589ms	remaining: 406ms
# 592:	learn: 30.7619271	total: 589ms	remaining: 404ms
# 593:	learn: 30.7486276	total: 590ms	remaining: 403ms
# 594:	learn: 30.7446523	total: 591ms	remaining: 402ms
# 595:	learn: 30.7426349	total: 591ms	remaining: 401ms
# 596:	learn: 30.7402335	total: 592ms	remaining: 400ms
# 597:	learn: 30.7346447	total: 593ms	remaining: 399ms
# 598:	learn: 30.7255246	total: 594ms	remaining: 398ms
# 599:	learn: 30.7199882	total: 595ms	remaining: 396ms
# 600:	learn: 30.7107365	total: 595ms	remaining: 395ms
# 601:	learn: 30.6977398	total: 596ms	remaining: 394ms
# 602:	learn: 30.6835200	total: 597ms	remaining: 393ms
# 603:	learn: 30.6790411	total: 597ms	remaining: 392ms
# 604:	learn: 30.6666611	total: 598ms	remaining: 390ms
# 605:	learn: 30.6660343	total: 599ms	remaining: 389ms
# 606:	learn: 30.6551163	total: 600ms	remaining: 388ms
# 607:	learn: 30.6455270	total: 601ms	remaining: 387ms
# 608:	learn: 30.6449089	total: 601ms	remaining: 386ms
# 609:	learn: 30.6402566	total: 602ms	remaining: 385ms
# 610:	learn: 30.6307777	total: 603ms	remaining: 384ms
# 611:	learn: 30.6242850	total: 604ms	remaining: 383ms
# 612:	learn: 30.6171289	total: 604ms	remaining: 381ms
# 613:	learn: 30.6163715	total: 605ms	remaining: 380ms
# 614:	learn: 30.6118341	total: 606ms	remaining: 379ms
# 615:	learn: 30.6090967	total: 606ms	remaining: 378ms
# 616:	learn: 30.6007043	total: 607ms	remaining: 377ms
# 617:	learn: 30.5999417	total: 608ms	remaining: 376ms
# 618:	learn: 30.5941330	total: 608ms	remaining: 374ms
# 619:	learn: 30.5886278	total: 609ms	remaining: 373ms
# 620:	learn: 30.5879630	total: 610ms	remaining: 372ms
# 621:	learn: 30.5763047	total: 610ms	remaining: 371ms
# 622:	learn: 30.5752331	total: 613ms	remaining: 371ms
# 623:	learn: 30.5682454	total: 614ms	remaining: 370ms
# 624:	learn: 30.5564373	total: 615ms	remaining: 369ms
# 625:	learn: 30.5484216	total: 616ms	remaining: 368ms
# 626:	learn: 30.5419940	total: 616ms	remaining: 367ms
# 627:	learn: 30.5414165	total: 617ms	remaining: 365ms
# 628:	learn: 30.5360536	total: 617ms	remaining: 364ms
# 629:	learn: 30.5228873	total: 618ms	remaining: 363ms
# 630:	learn: 30.5221904	total: 619ms	remaining: 362ms
# 631:	learn: 30.5215821	total: 620ms	remaining: 361ms
# 632:	learn: 30.5170733	total: 620ms	remaining: 360ms
# 633:	learn: 30.5164029	total: 621ms	remaining: 359ms
# 634:	learn: 30.5070856	total: 622ms	remaining: 357ms
# 635:	learn: 30.4973895	total: 623ms	remaining: 356ms
# 636:	learn: 30.4901263	total: 623ms	remaining: 355ms
# 637:	learn: 30.4836556	total: 624ms	remaining: 354ms
# 638:	learn: 30.4749959	total: 624ms	remaining: 353ms
# 639:	learn: 30.4670514	total: 627ms	remaining: 353ms
# 640:	learn: 30.4571367	total: 628ms	remaining: 352ms
# 641:	learn: 30.4544749	total: 629ms	remaining: 351ms
# 642:	learn: 30.4434978	total: 630ms	remaining: 350ms
# 643:	learn: 30.4366754	total: 631ms	remaining: 349ms
# 644:	learn: 30.4250438	total: 631ms	remaining: 348ms
# 645:	learn: 30.4189717	total: 632ms	remaining: 346ms
# 646:	learn: 30.4060278	total: 633ms	remaining: 345ms
# 647:	learn: 30.4024530	total: 634ms	remaining: 344ms
# 648:	learn: 30.3879536	total: 634ms	remaining: 343ms
# 649:	learn: 30.3804499	total: 635ms	remaining: 342ms
# 650:	learn: 30.3728179	total: 636ms	remaining: 341ms
# 651:	learn: 30.3678193	total: 637ms	remaining: 340ms
# 652:	learn: 30.3555077	total: 637ms	remaining: 339ms
# 653:	learn: 30.3505536	total: 638ms	remaining: 338ms
# 654:	learn: 30.3462501	total: 639ms	remaining: 336ms
# 655:	learn: 30.3396822	total: 641ms	remaining: 336ms
# 656:	learn: 30.3285934	total: 642ms	remaining: 335ms
# 657:	learn: 30.3281600	total: 643ms	remaining: 334ms
# 658:	learn: 30.3231630	total: 644ms	remaining: 333ms
# 659:	learn: 30.3192258	total: 644ms	remaining: 332ms
# 660:	learn: 30.3185441	total: 645ms	remaining: 331ms
# 661:	learn: 30.3152575	total: 646ms	remaining: 330ms
# 662:	learn: 30.3075237	total: 646ms	remaining: 328ms
# 663:	learn: 30.3044506	total: 647ms	remaining: 327ms
# 664:	learn: 30.2977360	total: 648ms	remaining: 326ms
# 665:	learn: 30.2968135	total: 648ms	remaining: 325ms
# 666:	learn: 30.2950982	total: 649ms	remaining: 324ms
# 667:	learn: 30.2945558	total: 650ms	remaining: 323ms
# 668:	learn: 30.2904528	total: 651ms	remaining: 322ms
# 669:	learn: 30.2828668	total: 651ms	remaining: 321ms
# 670:	learn: 30.2809145	total: 652ms	remaining: 320ms
# 671:	learn: 30.2729764	total: 653ms	remaining: 319ms
# 672:	learn: 30.2619328	total: 653ms	remaining: 318ms
# 673:	learn: 30.2443134	total: 656ms	remaining: 317ms
# 674:	learn: 30.2329945	total: 657ms	remaining: 316ms
# 675:	learn: 30.2196779	total: 658ms	remaining: 315ms
# 676:	learn: 30.2190786	total: 659ms	remaining: 314ms
# 677:	learn: 30.2142656	total: 660ms	remaining: 313ms
# 678:	learn: 30.2061330	total: 660ms	remaining: 312ms
# 679:	learn: 30.2008578	total: 661ms	remaining: 311ms
# 680:	learn: 30.1949765	total: 662ms	remaining: 310ms
# 681:	learn: 30.1903065	total: 663ms	remaining: 309ms
# 682:	learn: 30.1839230	total: 664ms	remaining: 308ms
# 683:	learn: 30.1833967	total: 664ms	remaining: 307ms
# 684:	learn: 30.1829894	total: 665ms	remaining: 306ms
# 685:	learn: 30.1778227	total: 666ms	remaining: 305ms
# 686:	learn: 30.1755435	total: 666ms	remaining: 303ms
# 687:	learn: 30.1727993	total: 667ms	remaining: 302ms
# 688:	learn: 30.1666773	total: 668ms	remaining: 301ms
# 689:	learn: 30.1608323	total: 668ms	remaining: 300ms
# 690:	learn: 30.1602154	total: 670ms	remaining: 300ms
# 691:	learn: 30.1566263	total: 672ms	remaining: 299ms
# 692:	learn: 30.1545179	total: 673ms	remaining: 298ms
# 693:	learn: 30.1539634	total: 674ms	remaining: 297ms
# 694:	learn: 30.1453341	total: 674ms	remaining: 296ms
# 695:	learn: 30.1324197	total: 675ms	remaining: 295ms
# 696:	learn: 30.1220193	total: 676ms	remaining: 294ms
# 697:	learn: 30.1109436	total: 676ms	remaining: 293ms
# 698:	learn: 30.1105167	total: 677ms	remaining: 291ms
# 699:	learn: 30.1042708	total: 677ms	remaining: 290ms
# 700:	learn: 30.1032092	total: 678ms	remaining: 289ms
# 701:	learn: 30.0996011	total: 679ms	remaining: 288ms
# 702:	learn: 30.0977212	total: 680ms	remaining: 287ms
# 703:	learn: 30.0882263	total: 680ms	remaining: 286ms
# 704:	learn: 30.0750473	total: 681ms	remaining: 285ms
# 705:	learn: 30.0746335	total: 682ms	remaining: 284ms
# 706:	learn: 30.0738209	total: 682ms	remaining: 283ms
# 707:	learn: 30.0734284	total: 683ms	remaining: 282ms
# 708:	learn: 30.0704477	total: 684ms	remaining: 281ms
# 709:	learn: 30.0652820	total: 686ms	remaining: 280ms
# 710:	learn: 30.0461799	total: 687ms	remaining: 279ms
# 711:	learn: 30.0405570	total: 688ms	remaining: 278ms
# 712:	learn: 30.0254070	total: 689ms	remaining: 277ms
# 713:	learn: 30.0234675	total: 690ms	remaining: 276ms
# 714:	learn: 30.0110661	total: 690ms	remaining: 275ms
# 715:	learn: 30.0051871	total: 691ms	remaining: 274ms
# 716:	learn: 29.9959345	total: 692ms	remaining: 273ms
# 717:	learn: 29.9880125	total: 693ms	remaining: 272ms
# 718:	learn: 29.9874172	total: 693ms	remaining: 271ms
# 719:	learn: 29.9726204	total: 695ms	remaining: 270ms
# 720:	learn: 29.9564285	total: 696ms	remaining: 269ms
# 721:	learn: 29.9470388	total: 697ms	remaining: 268ms
# 722:	learn: 29.9408631	total: 698ms	remaining: 267ms
# 723:	learn: 29.9334956	total: 699ms	remaining: 267ms
# 724:	learn: 29.9330646	total: 700ms	remaining: 266ms
# 725:	learn: 29.9308467	total: 702ms	remaining: 265ms
# 726:	learn: 29.9258569	total: 703ms	remaining: 264ms
# 727:	learn: 29.9241754	total: 704ms	remaining: 263ms
# 728:	learn: 29.9237341	total: 705ms	remaining: 262ms
# 729:	learn: 29.9137408	total: 706ms	remaining: 261ms
# 730:	learn: 29.9121747	total: 707ms	remaining: 260ms
# 731:	learn: 29.9014207	total: 708ms	remaining: 259ms
# 732:	learn: 29.9010966	total: 708ms	remaining: 258ms
# 733:	learn: 29.8972024	total: 709ms	remaining: 257ms
# 734:	learn: 29.8967369	total: 710ms	remaining: 256ms
# 735:	learn: 29.8864502	total: 711ms	remaining: 255ms
# 736:	learn: 29.8764089	total: 711ms	remaining: 254ms
# 737:	learn: 29.8694082	total: 712ms	remaining: 253ms
# 738:	learn: 29.8690577	total: 712ms	remaining: 252ms
# 739:	learn: 29.8655654	total: 713ms	remaining: 251ms
# 740:	learn: 29.8626300	total: 716ms	remaining: 250ms
# 741:	learn: 29.8542606	total: 717ms	remaining: 249ms
# 742:	learn: 29.8454425	total: 719ms	remaining: 249ms
# 743:	learn: 29.8385342	total: 720ms	remaining: 248ms
# 744:	learn: 29.8347387	total: 721ms	remaining: 247ms
# 745:	learn: 29.8325951	total: 721ms	remaining: 246ms
# 746:	learn: 29.8240556	total: 722ms	remaining: 245ms
# 747:	learn: 29.8166013	total: 723ms	remaining: 244ms
# 748:	learn: 29.8080965	total: 724ms	remaining: 243ms
# 749:	learn: 29.8077585	total: 725ms	remaining: 242ms
# 750:	learn: 29.8018574	total: 725ms	remaining: 241ms
# 751:	learn: 29.7999858	total: 726ms	remaining: 239ms
# 752:	learn: 29.7929920	total: 727ms	remaining: 238ms
# 753:	learn: 29.7913190	total: 728ms	remaining: 237ms
# 754:	learn: 29.7872900	total: 728ms	remaining: 236ms
# 755:	learn: 29.7751692	total: 731ms	remaining: 236ms
# 756:	learn: 29.7688203	total: 732ms	remaining: 235ms
# 757:	learn: 29.7625638	total: 733ms	remaining: 234ms
# 758:	learn: 29.7622738	total: 734ms	remaining: 233ms
# 759:	learn: 29.7619788	total: 735ms	remaining: 232ms
# 760:	learn: 29.7570563	total: 735ms	remaining: 231ms
# 761:	learn: 29.7566588	total: 736ms	remaining: 230ms
# 762:	learn: 29.7546674	total: 737ms	remaining: 229ms
# 763:	learn: 29.7469837	total: 737ms	remaining: 228ms
# 764:	learn: 29.7422366	total: 738ms	remaining: 227ms
# 765:	learn: 29.7401067	total: 739ms	remaining: 226ms
# 766:	learn: 29.7371594	total: 740ms	remaining: 225ms
# 767:	learn: 29.7368295	total: 740ms	remaining: 224ms
# 768:	learn: 29.7274163	total: 741ms	remaining: 223ms
# 769:	learn: 29.7226792	total: 742ms	remaining: 222ms
# 770:	learn: 29.7159945	total: 743ms	remaining: 221ms
# 771:	learn: 29.7103335	total: 743ms	remaining: 220ms
# 772:	learn: 29.7087465	total: 745ms	remaining: 219ms
# 773:	learn: 29.7012991	total: 746ms	remaining: 218ms
# 774:	learn: 29.6884189	total: 746ms	remaining: 217ms
# 775:	learn: 29.6824233	total: 747ms	remaining: 216ms
# 776:	learn: 29.6736351	total: 748ms	remaining: 215ms
# 777:	learn: 29.6648839	total: 749ms	remaining: 214ms
# 778:	learn: 29.6645111	total: 749ms	remaining: 213ms
# 779:	learn: 29.6585536	total: 750ms	remaining: 212ms
# 780:	learn: 29.6519661	total: 751ms	remaining: 210ms
# 781:	learn: 29.6463890	total: 751ms	remaining: 209ms
# 782:	learn: 29.6440115	total: 752ms	remaining: 208ms
# 783:	learn: 29.6435707	total: 753ms	remaining: 207ms
# 784:	learn: 29.6416914	total: 754ms	remaining: 206ms
# 785:	learn: 29.6345973	total: 755ms	remaining: 205ms
# 786:	learn: 29.6336766	total: 755ms	remaining: 204ms
# 787:	learn: 29.6333199	total: 756ms	remaining: 203ms
# 788:	learn: 29.6291840	total: 756ms	remaining: 202ms
# 789:	learn: 29.6275285	total: 759ms	remaining: 202ms
# 790:	learn: 29.6221421	total: 760ms	remaining: 201ms
# 791:	learn: 29.6176107	total: 761ms	remaining: 200ms
# 792:	learn: 29.6130017	total: 761ms	remaining: 199ms
# 793:	learn: 29.6058675	total: 762ms	remaining: 198ms
# 794:	learn: 29.6033799	total: 763ms	remaining: 197ms
# 795:	learn: 29.6000427	total: 764ms	remaining: 196ms
# 796:	learn: 29.5936376	total: 765ms	remaining: 195ms
# 797:	learn: 29.5844631	total: 765ms	remaining: 194ms
# 798:	learn: 29.5808165	total: 766ms	remaining: 193ms
# 799:	learn: 29.5736358	total: 767ms	remaining: 192ms
# 800:	learn: 29.5707852	total: 768ms	remaining: 191ms
# 801:	learn: 29.5651716	total: 768ms	remaining: 190ms
# 802:	learn: 29.5581160	total: 769ms	remaining: 189ms
# 803:	learn: 29.5469894	total: 771ms	remaining: 188ms
# 804:	learn: 29.5396366	total: 771ms	remaining: 187ms
# 805:	learn: 29.5392799	total: 772ms	remaining: 186ms
# 806:	learn: 29.5379857	total: 774ms	remaining: 185ms
# 807:	learn: 29.5344013	total: 776ms	remaining: 184ms
# 808:	learn: 29.5267967	total: 777ms	remaining: 183ms
# 809:	learn: 29.5131429	total: 778ms	remaining: 182ms
# 810:	learn: 29.5092255	total: 778ms	remaining: 181ms
# 811:	learn: 29.5007749	total: 779ms	remaining: 180ms
# 812:	learn: 29.4950492	total: 780ms	remaining: 179ms
# 813:	learn: 29.4946591	total: 780ms	remaining: 178ms
# 814:	learn: 29.4860444	total: 781ms	remaining: 177ms
# 815:	learn: 29.4836629	total: 782ms	remaining: 176ms
# 816:	learn: 29.4797137	total: 783ms	remaining: 175ms
# 817:	learn: 29.4794477	total: 784ms	remaining: 174ms
# 818:	learn: 29.4660008	total: 785ms	remaining: 173ms
# 819:	learn: 29.4636431	total: 785ms	remaining: 172ms
# 820:	learn: 29.4583733	total: 786ms	remaining: 171ms
# 821:	learn: 29.4512228	total: 789ms	remaining: 171ms
# 822:	learn: 29.4508776	total: 790ms	remaining: 170ms
# 823:	learn: 29.4454820	total: 791ms	remaining: 169ms
# 824:	learn: 29.4441071	total: 792ms	remaining: 168ms
# 825:	learn: 29.4437952	total: 793ms	remaining: 167ms
# 826:	learn: 29.4411288	total: 794ms	remaining: 166ms
# 827:	learn: 29.4387139	total: 794ms	remaining: 165ms
# 828:	learn: 29.4384632	total: 795ms	remaining: 164ms
# 829:	learn: 29.4308408	total: 796ms	remaining: 163ms
# 830:	learn: 29.4262173	total: 797ms	remaining: 162ms
# 831:	learn: 29.4185709	total: 798ms	remaining: 161ms
# 832:	learn: 29.4122712	total: 799ms	remaining: 160ms
# 833:	learn: 29.4070058	total: 799ms	remaining: 159ms
# 834:	learn: 29.4044579	total: 800ms	remaining: 158ms
# 835:	learn: 29.4029685	total: 802ms	remaining: 157ms
# 836:	learn: 29.4023145	total: 804ms	remaining: 156ms
# 837:	learn: 29.4017642	total: 804ms	remaining: 156ms
# 838:	learn: 29.3962563	total: 805ms	remaining: 155ms
# 839:	learn: 29.3958790	total: 807ms	remaining: 154ms
# 840:	learn: 29.3929130	total: 808ms	remaining: 153ms
# 841:	learn: 29.3926177	total: 815ms	remaining: 153ms
# 842:	learn: 29.3912022	total: 816ms	remaining: 152ms
# 843:	learn: 29.3909063	total: 819ms	remaining: 151ms
# 844:	learn: 29.3812683	total: 820ms	remaining: 150ms
# 845:	learn: 29.3730233	total: 822ms	remaining: 150ms
# 846:	learn: 29.3696314	total: 824ms	remaining: 149ms
# 847:	learn: 29.3662492	total: 825ms	remaining: 148ms
# 848:	learn: 29.3659739	total: 831ms	remaining: 148ms
# 849:	learn: 29.3599637	total: 833ms	remaining: 147ms
# 850:	learn: 29.3536131	total: 834ms	remaining: 146ms
# 851:	learn: 29.3516513	total: 835ms	remaining: 145ms
# 852:	learn: 29.3503230	total: 837ms	remaining: 144ms
# 853:	learn: 29.3417926	total: 838ms	remaining: 143ms
# 854:	learn: 29.3351595	total: 839ms	remaining: 142ms
# 855:	learn: 29.3234317	total: 839ms	remaining: 141ms
# 856:	learn: 29.3162281	total: 846ms	remaining: 141ms
# 857:	learn: 29.3159358	total: 847ms	remaining: 140ms
# 858:	learn: 29.3098989	total: 848ms	remaining: 139ms
# 859:	learn: 29.3072534	total: 849ms	remaining: 138ms
# 860:	learn: 29.2988762	total: 851ms	remaining: 137ms
# 861:	learn: 29.2954456	total: 853ms	remaining: 136ms
# 862:	learn: 29.2918159	total: 853ms	remaining: 135ms
# 863:	learn: 29.2875076	total: 858ms	remaining: 135ms
# 864:	learn: 29.2872870	total: 859ms	remaining: 134ms
# 865:	learn: 29.2830256	total: 860ms	remaining: 133ms
# 866:	learn: 29.2688239	total: 861ms	remaining: 132ms
# 867:	learn: 29.2631554	total: 862ms	remaining: 131ms
# 868:	learn: 29.2584973	total: 863ms	remaining: 130ms
# 869:	learn: 29.2531837	total: 864ms	remaining: 129ms
# 870:	learn: 29.2434788	total: 865ms	remaining: 128ms
# 871:	learn: 29.2432026	total: 866ms	remaining: 127ms
# 872:	learn: 29.2399178	total: 869ms	remaining: 126ms
# 873:	learn: 29.2396324	total: 873ms	remaining: 126ms
# 874:	learn: 29.2298932	total: 874ms	remaining: 125ms
# 875:	learn: 29.2274802	total: 875ms	remaining: 124ms
# 876:	learn: 29.2200966	total: 876ms	remaining: 123ms
# 877:	learn: 29.2133286	total: 877ms	remaining: 122ms
# 878:	learn: 29.2103404	total: 878ms	remaining: 121ms
# 879:	learn: 29.2058285	total: 879ms	remaining: 120ms
# 880:	learn: 29.2055522	total: 880ms	remaining: 119ms
# 881:	learn: 29.2052187	total: 881ms	remaining: 118ms
# 882:	learn: 29.2033959	total: 890ms	remaining: 118ms
# 883:	learn: 29.2031697	total: 891ms	remaining: 117ms
# 884:	learn: 29.1976684	total: 892ms	remaining: 116ms
# 885:	learn: 29.1923492	total: 894ms	remaining: 115ms
# 886:	learn: 29.1904315	total: 895ms	remaining: 114ms
# 887:	learn: 29.1901805	total: 896ms	remaining: 113ms
# 888:	learn: 29.1859028	total: 897ms	remaining: 112ms
# 889:	learn: 29.1856470	total: 897ms	remaining: 111ms
# 890:	learn: 29.1838710	total: 898ms	remaining: 110ms
# 891:	learn: 29.1751318	total: 901ms	remaining: 109ms
# 892:	learn: 29.1686719	total: 911ms	remaining: 109ms
# 893:	learn: 29.1684337	total: 913ms	remaining: 108ms
# 894:	learn: 29.1624438	total: 914ms	remaining: 107ms
# 895:	learn: 29.1593074	total: 914ms	remaining: 106ms
# 896:	learn: 29.1528002	total: 918ms	remaining: 105ms
# 897:	learn: 29.1451051	total: 919ms	remaining: 104ms
# 898:	learn: 29.1397448	total: 921ms	remaining: 104ms
# 899:	learn: 29.1320899	total: 923ms	remaining: 103ms
# 900:	learn: 29.1318492	total: 924ms	remaining: 102ms
# 901:	learn: 29.1176778	total: 926ms	remaining: 101ms
# 902:	learn: 29.1151552	total: 928ms	remaining: 99.7ms
# 903:	learn: 29.1027065	total: 929ms	remaining: 98.6ms
# 904:	learn: 29.0957829	total: 934ms	remaining: 98ms
# 905:	learn: 29.0946693	total: 936ms	remaining: 97.2ms
# 906:	learn: 29.0943929	total: 938ms	remaining: 96.2ms
# 907:	learn: 29.0896526	total: 939ms	remaining: 95.2ms
# 908:	learn: 29.0894274	total: 940ms	remaining: 94.1ms
# 909:	learn: 29.0884749	total: 941ms	remaining: 93.1ms
# 910:	learn: 29.0809483	total: 942ms	remaining: 92ms
# 911:	learn: 29.0705627	total: 945ms	remaining: 91.2ms
# 912:	learn: 29.0680679	total: 947ms	remaining: 90.2ms
# 913:	learn: 29.0598676	total: 947ms	remaining: 89.1ms
# 914:	learn: 29.0549554	total: 948ms	remaining: 88.1ms
# 915:	learn: 29.0425893	total: 949ms	remaining: 87ms
# 916:	learn: 29.0378088	total: 949ms	remaining: 85.9ms
# 917:	learn: 29.0375628	total: 952ms	remaining: 85ms
# 918:	learn: 29.0332618	total: 953ms	remaining: 84ms
# 919:	learn: 29.0273382	total: 954ms	remaining: 83ms
# 920:	learn: 29.0270460	total: 955ms	remaining: 81.9ms
# 921:	learn: 29.0254086	total: 956ms	remaining: 80.9ms
# 922:	learn: 29.0144747	total: 959ms	remaining: 80ms
# 923:	learn: 29.0118555	total: 960ms	remaining: 78.9ms
# 924:	learn: 29.0031270	total: 961ms	remaining: 78ms
# 925:	learn: 29.0020587	total: 963ms	remaining: 77ms
# 926:	learn: 28.9990610	total: 965ms	remaining: 76ms
# 927:	learn: 28.9988392	total: 966ms	remaining: 75ms
# 928:	learn: 28.9951576	total: 968ms	remaining: 74ms
# 929:	learn: 28.9949681	total: 969ms	remaining: 73ms
# 930:	learn: 28.9860656	total: 970ms	remaining: 71.9ms
# 931:	learn: 28.9818758	total: 972ms	remaining: 70.9ms
# 932:	learn: 28.9776155	total: 974ms	remaining: 69.9ms
# 933:	learn: 28.9732002	total: 974ms	remaining: 68.9ms
# 934:	learn: 28.9656106	total: 976ms	remaining: 67.8ms
# 935:	learn: 28.9547222	total: 977ms	remaining: 66.8ms
# 936:	learn: 28.9483464	total: 978ms	remaining: 65.8ms
# 937:	learn: 28.9466855	total: 981ms	remaining: 64.9ms
# 938:	learn: 28.9407394	total: 983ms	remaining: 63.8ms
# 939:	learn: 28.9404784	total: 984ms	remaining: 62.8ms
# 940:	learn: 28.9318336	total: 985ms	remaining: 61.8ms
# 941:	learn: 28.9221611	total: 987ms	remaining: 60.7ms
# 942:	learn: 28.9184276	total: 987ms	remaining: 59.7ms
# 943:	learn: 28.9108704	total: 989ms	remaining: 58.7ms
# 944:	learn: 28.9056695	total: 990ms	remaining: 57.6ms
# 945:	learn: 28.8980163	total: 991ms	remaining: 56.6ms
# 946:	learn: 28.8977151	total: 993ms	remaining: 55.6ms
# 947:	learn: 28.8898308	total: 994ms	remaining: 54.5ms
# 948:	learn: 28.8861961	total: 995ms	remaining: 53.5ms
# 949:	learn: 28.8812907	total: 997ms	remaining: 52.5ms
# 950:	learn: 28.8791039	total: 998ms	remaining: 51.4ms
# 951:	learn: 28.8706410	total: 1000ms	remaining: 50.4ms
# 952:	learn: 28.8672401	total: 1s	remaining: 49.4ms
# 953:	learn: 28.8546844	total: 1s	remaining: 48.4ms
# 954:	learn: 28.8432139	total: 1s	remaining: 47.3ms
# 955:	learn: 28.8391323	total: 1s	remaining: 46.3ms
# 956:	learn: 28.8336290	total: 1.01s	remaining: 45.3ms
# 957:	learn: 28.8306740	total: 1.01s	remaining: 44.3ms
# 958:	learn: 28.8222114	total: 1.01s	remaining: 43.2ms
# 959:	learn: 28.8159360	total: 1.01s	remaining: 42.2ms
# 960:	learn: 28.8135757	total: 1.01s	remaining: 41.1ms
# 961:	learn: 28.8039269	total: 1.01s	remaining: 40.1ms
# 962:	learn: 28.7966395	total: 1.02s	remaining: 39ms
# 963:	learn: 28.7860954	total: 1.02s	remaining: 38.1ms
# 964:	learn: 28.7804569	total: 1.02s	remaining: 37ms
# 965:	learn: 28.7752447	total: 1.02s	remaining: 36ms
# 966:	learn: 28.7733999	total: 1.02s	remaining: 34.9ms
# 967:	learn: 28.7707185	total: 1.02s	remaining: 33.9ms
# 968:	learn: 28.7641518	total: 1.02s	remaining: 32.8ms
# 969:	learn: 28.7591029	total: 1.03s	remaining: 31.8ms
# 970:	learn: 28.7549542	total: 1.03s	remaining: 30.7ms
# 971:	learn: 28.7520298	total: 1.03s	remaining: 29.7ms
# 972:	learn: 28.7487635	total: 1.03s	remaining: 28.6ms
# 973:	learn: 28.7420788	total: 1.03s	remaining: 27.6ms
# 974:	learn: 28.7346196	total: 1.03s	remaining: 26.6ms
# 975:	learn: 28.7343970	total: 1.04s	remaining: 25.5ms
# 976:	learn: 28.7336077	total: 1.04s	remaining: 24.4ms
# 977:	learn: 28.7332974	total: 1.04s	remaining: 23.4ms
# 978:	learn: 28.7161436	total: 1.04s	remaining: 22.3ms
# 979:	learn: 28.7131120	total: 1.04s	remaining: 21.2ms
# 980:	learn: 28.7079595	total: 1.04s	remaining: 20.2ms
# 981:	learn: 28.7068893	total: 1.04s	remaining: 19.1ms
# 982:	learn: 28.7018972	total: 1.04s	remaining: 18.1ms
# 983:	learn: 28.7009314	total: 1.05s	remaining: 17.1ms
# 984:	learn: 28.6859964	total: 1.05s	remaining: 16ms
# 985:	learn: 28.6803473	total: 1.05s	remaining: 14.9ms
# 986:	learn: 28.6801183	total: 1.05s	remaining: 13.9ms
# 987:	learn: 28.6709358	total: 1.05s	remaining: 12.8ms
# 988:	learn: 28.6641891	total: 1.05s	remaining: 11.7ms
# 989:	learn: 28.6639965	total: 1.06s	remaining: 10.7ms
# 990:	learn: 28.6610188	total: 1.06s	remaining: 9.61ms
# 991:	learn: 28.6565632	total: 1.06s	remaining: 8.56ms
# 992:	learn: 28.6511666	total: 1.06s	remaining: 7.49ms
# 993:	learn: 28.6433570	total: 1.06s	remaining: 6.42ms
# 994:	learn: 28.6396976	total: 1.06s	remaining: 5.35ms
# 995:	learn: 28.6394097	total: 1.06s	remaining: 4.28ms
# 996:	learn: 28.6355459	total: 1.07s	remaining: 3.21ms
# 997:	learn: 28.6353033	total: 1.07s	remaining: 2.14ms
# 998:	learn: 28.6323333	total: 1.07s	remaining: 1.07ms
# 999:	learn: 28.6273099	total: 1.07s	remaining: 0us

# %% [markdown]
# #### Cat Boost Regressor Visuals

# %%
print(f"R-squared value for train data: {cat_model_train}")
print(f"R-squared value for test data: {cat_model_test}")
print(f"Average Missed Distance From Price: {mean_squared_error(y_test, y_pred_test, squared = False)}")
# Out:
# R-squared value for train data: 0.6911675671039983
# R-squared value for test data: 0.4924641834108424
# Average Missed Distance From Price: 36.71564130927711

# %%
plt.rcParams['figure.figsize'] = [10, 6]

plt.scatter(y_test, y_pred_test, color = 'black')
plt.title('Scatter Plot Of CatBoostRegressor Result')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price');

# %% [markdown]
# ### Step 4: R-Squared Visualization
# > **Now that we have obtained the R-squared scores of both data using different models, I will be comparing each one against each other.**

# %%
scores_train = [svr_model_train, xgb_model_train, baye_model_train, 
                rfc_model_train, gradient_model_train, cat_model_train]
scores_test = [svr_model_test, xgb_model_test, baye_model_test, 
                rfc_model_test, gradient_model_test, cat_model_test]
labels = ['Support Vector Machine', 'XGB Regressor', 'Bayesian Ridge',
         'Random Forest Classifier', 'Gradient Boosting Regressor', 'Cat Boost Regressor']

# %%
plt.rcParams['figure.figsize'] = [15, 8]

plt.scatter(labels, scores_train, color = 'blue')
plt.scatter(labels, scores_test, color = 'black')
plt.legend(['scores_train', 'scores_test'])
plt.ylabel('Score', fontsize = 15)
plt.xlabel('Models', fontsize = 15)
plt.title('Scores Of All Algorithm/Method Used', fontsize = 20)
plt.savefig('Scores Of All Method Used.png');

# %% [markdown]
# **Here, we can see that the Support Method Machine and Bayesian Ridge Models have the smallest gap while the Random Forest Classifer has the widest one. However, our models fail at explaining the prices for different independent variables. Therefore, I can conclude that we have not found the best model, but this is a good start.** <br>
#
# **However, looking at the model and if I had to choose 2 models, I would go for Gradient Boosting Regressor(GBR) and Bayesian Ridge, in that order. Firstly, Bayesian Ridge has similair distance to the Support Vector Machine model but the r2 scores for the train and test data are higher.**
#
# **In terms of percantage, GBR's r2 scores has a slightly larger distance between one another, but both scores are higher than Bayesian Ridge. In other words, I would say that the distance is small enough for me to consider it as a usable model(out of all the ones presented).**
